# %%
from sklearn.cluster import KMeans
from collections import Counter
from matplotlib import pyplot as plt
import cv2
from sklearn.cluster import KMeans
from collections import Counter
from matplotlib import pyplot as plt
import cv2
# %matplotlib inline
import numpy as np 
from skimage import io
from skimage import feature
from skimage.color import rgb2gray
import os
from glob import glob
import numpy as np

# %%
img = cv2.imread('1-1.png')
#cv2.imshow("image", img)
ret,thresh = cv2.threshold(img,127,255,0)

# %%
thresh
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
z = cv2.findContours(thresh, 1, 2) 
contours,hierarchy=z
cnt = contours[0]
M = cv2.moments(cnt)
print (M)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-673432714c13> in <module>
#       1 z = cv2.findContours(thresh, 1, 2)
# ----> 2 contours,hierarchy=z
#       3 cnt = contours[0]
#       4 M = cv2.moments(cnt)
#       5 print (M)
#
# ValueError: too many values to unpack (expected 2)

# %%
cx = int(M['m10']/M['m00'])
cy = int(M['m01']/M['m00'])

# %%
area = cv2.contourArea(cnt)
perimeter = cv2.arcLength(cnt,True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5aec49bfc30c> in <module>
# ----> 1 area = cv2.contourArea(cnt)
#       2 perimeter = cv2.arcLength(cnt,True)
#
# NameError: name 'cnt' is not defined

# %%
x,y,w,h = cv2.boundingRect(cnt)
a=cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),5)

# %%
(x,y,w,h)
# Out:
# (0, 0, 640, 480)

# %%
cv2.imwrite( "Image.jpg", a );

# %%
#finding last pixeleted value
def gety(img,t,sha):
    
    x=sha[0]
    y=sha[1]
    if(t=="f"):
        for i in range(0,x):
            for j in range(0,y):
                if(img[i][j]==1):
                    return i
    if(t=="l"):
        for i in range(x-1,0,-1):
            for j in range(0,y):
                if(img[i][j]==1):
                    return i

# %%
#finding last pixeleted value
def getx(img,t,sha):
    
    x=sha[0]
    y=sha[1]
    if(t=="f"):
        for i in range(0,y):
            for j in range(0,x):
                if(img[j][i]==1):
                    return i
    if(t=="l"):
        for i in range(y-1,0,-1):
            for j in range(0,x):
                if(img[j][i]==1):
                    return i

# %%
x1=io.imread("test2.png")
fl.median(image[, selem, out, …])

# %%
io.imshow(x1)

# %%
from skimage import morphology as mp
from skimage import filters as fl
from skimage import data, img_as_float
from skimage.util import random_noise
from skimage.filters.rank import median
from skimage.morphology import disk

# %%
x1=io.imread("test2.png")
#x2=denoise_bilateral(x1, sigma_color=0.1, sigma_spatial=15,multichannel=True)
"""x2=rgb2gray(x1)
x3 = feature.canny(x2,0.9,.89,0)
x3=fl.gaussian(x3)
zx=mp.binary_erosion(x3)
io.imshow(mp.binary_erosion(x3))
zx=mp.binary_erosion(x3)
"""

#io.imshow(fl.gaussian((fl.gaussian((fl.gaussian(fl.gaussian(x3)))))))
io.imsave("ou.png",x2)

# %%
x1=io.imread("t3.png")
#case 4 use of gaussian before rgb case 5 use of gaussian after canny
io.imshow(x1)

# %%
x11=fl.gaussian(x1)

io.imshow(x11)

# %%
x2=rgb2gray(x11)
io.imshow(x2)

# %%
x22=mean(x2,disk(5))
#x22=x2
io.imshow(x22)

# %%
from skimage import morphology
#cleaned = morphology.remove_small_objects(YOUR_IMAGE, min_size=64, connectivity=2)

# %%
  #x2=median(x2, disk(1))
    #case1
    #x3 = feature.canny(x2, .5, 0.5, 0.7)
    
    #case2
"""
x3 = feature.canny(x2,1,.9,.8)
    x3=fl.gaussian(x3)
    x3=mp.binary_erosion(x3)
"""
    
    #case3
    #x3 = feature.canny(x2,0.5,.8,0)
#x33=fl.gaussian(x22)
x3 = feature.canny(x2,0.6,0.5,0.3)
x33 = morphology.remove_small_objects(x3, min_size=16, connectivity=20)
#x11=median(x11)
io.imshow(x33)
io.imsave("ou.png",x33)
    #.9,.7,.8

# %%
from skimage.filters.rank import mean

# %%
x1=io.imread("t2.png")
#case 4 use of gaussian before rgb case 5 use of gaussian after canny
#io.imshow(x1)
x11=fl.gaussian(x1)
#io.imshow(x1)
x2=rgb2gray(x1)
#io.imshow(x2)
#x2=fl.gaussian(x2)
x3 = feature.canny(x2,0.5,0.4,0.1)

x3 = morphology.remove_small_objects(x3)

x3 = feature.canny(x2,0.9,0.8,0.1)

x3=fl.gaussian(x3)
#x3=mp.binary_erosion(x3)
x3=mp.binary_opening(x3)
#x33 = morphology.remove_small_objects(x3)
#x11=median(x11)
io.imshow(x3)
io.imsave("out.png",x3)

# %%
sha=x33.shape
arr=[getx(x33,"f",sha),getx(x33,"l",sha),gety(x33,"f",sha),gety(x33,"l",sha)]
arr
io.imshow(x2)

# %%
arr
# Out:
# [14, 638, 115, 321]

# %%
x4=mean(x3,disk(2))
#x4=median(x4,disk(1))
io.imsave("ou.png",x4)

io.imshow(x4)

# %%
io.imshow(x3)

# %%
x3.shape
# Out:
# (480, 640)

# %%
sha=x3.shape

# %%
sha
# Out:
# (480, 640)

# %%
getx(x3,"f",sha)
# Out:
# 127

# %%
# %%time
#list contains [x1,x2,y1,y2]

arr=[getx(x3,"f",sha),getx(x3,"l",sha),gety(x3,"f",sha),gety(x3,"l",sha)]
# Out:
# Wall time: 258 ms

# %%
arr
# Out:
# [127, 512, 66, 413]

# %%
x,y,w,h = [arr[0],arr[2],arr[1]-arr[0],arr[3]-arr[2]]
a=cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),5)

# %%
cv2.imwrite( "Image.jpg", a );
